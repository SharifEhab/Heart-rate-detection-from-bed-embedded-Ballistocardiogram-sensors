# %% [markdown]
# Data Loading & Parsing
#
# Resampling (140 Hz→50 Hz)
#
# Body‑Movement & Bed‑Occupancy Detection
#
# DWT S4 Extraction (J‑peak emphasis)
#
# J‑Peak Detection
#
# BCG‑based HR Calculation
#
# Reference HR Extraction (RR files via Pan–Tompkins)
#
# Synchronization of BCG & ECG HR
#
# Error Metrics & Statistics
#
# Plots & Reporting

# %% [markdown]
# ### This notebook is for testing and running functions separately to ensure correctness

# %%
import os
import pandas as pd

DATA_ROOT = "../dataset/data"

def parse_filename(fn):
    """
    Parse names like "01_20231104_BCG.csv" → subject="01", date="20231104", dtype="BCG"
    """
    base, _ = os.path.splitext(fn)
    subj, date, dtype = base.split("_")
    return subj, date, dtype

def discover_files(data_root=DATA_ROOT):
    """
    Walks data_root and returns a dict:
        files[subj][date] = {"BCG": [paths...], "RR": [paths...], "resp": [...]}
    """
    files = {}
    for subj in sorted(os.listdir(data_root)):
        subj_dir = os.path.join(data_root, subj)
        if not os.path.isdir(subj_dir):
            continue
        files[subj] = {}
        # BCG folder
        for dtype in ("BCG", "Reference"):
            dpath = os.path.join(subj_dir, dtype)
            if not os.path.isdir(dpath):
                continue
            # handle RR and resp under Reference
            if dtype == "BCG":
                for fn in os.listdir(dpath):
                    if not fn.endswith(".csv"):
                        continue
                    _, date, dt = parse_filename(fn)
                    files[subj].setdefault(date, {}).setdefault("BCG", []).append(os.path.join(dpath, fn))
            else:
                # Reference/RR and Reference/resp
                for ref_type in ("RR", "resp"):
                    rpath = os.path.join(dpath, ref_type)
                    if not os.path.isdir(rpath):
                        continue
                    for fn in os.listdir(rpath):
                        if not fn.endswith(".csv"):
                            continue
                        _, date, dt = parse_filename(fn)
                        files[subj].setdefault(date, {}).setdefault(dt, []).append(os.path.join(rpath, fn))
    return files

# Discover
files = discover_files()
print(files)
print("____________*******************&&&&&&&&&&&&&&&&^^^^^^^^^^$$$$$$$$$$")
# Summarize
for subj, dates in files.items():
    total_dates = len(dates)
    with_rr = sum(1 for d in dates.values() if "RR" in d)
    with_bcg = sum(1 for d in dates.values() if "BCG" in d)
    print(f"Subject {subj}: {total_dates} dates, {with_bcg} have BCG, {with_rr} have RR reference")

# List example for subject "01"
print("\nExample entries for subject 01:")
for date, types in files["01"].items():
    print(f"  Date {date}: has BCG×{len(types.get('BCG',[]))}, RR×{len(types.get('RR',[]))}, resp×{len(types.get('resp',[]))}")
# Out:
# {'01': {'20231104': {'BCG': ['../dataset/data\\01\\BCG\\01_20231104_BCG.csv'], 'RR': ['../dataset/data\\01\\Reference\\RR\\01_20231104_RR.csv']}, '20231105': {'BCG': ['../dataset/data\\01\\BCG\\01_20231105_BCG.csv'], 'RR': ['../dataset/data\\01\\Reference\\RR\\01_20231105_RR.csv']}, '20231106': {'BCG': ['../dataset/data\\01\\BCG\\01_20231106_BCG.csv']}, '20231107': {'BCG': ['../dataset/data\\01\\BCG\\01_20231107_BCG.csv']}, '20231108': {'BCG': ['../dataset/data\\01\\BCG\\01_20231108_BCG.csv']}, '
20231109': {'BCG': ['../dataset/data\\05\\BCG\\05_20231109_BCG.csv']}}, '06': {'20231110': {'BCG': ['../dataset/data\\06\\BCG\\06_20231110_BCG.csv'], 'RR': ['../dataset/data\\06\\Reference\\RR\\06_20231110_RR.csv']}, '20231111': {'BCG': ['../dataset/data\\06\\BCG\\06_20231111_BCG.csv'], 'RR': ['../dataset/data\\06\\Reference\\RR\\06_20231111_RR.csv']}, '20231112': {'BCG': ['../dataset/data\\06\\BCG\\06_20231112_BCG.csv']}, '20231113': {'BCG': ['../dataset/data\\06\\BCG\\06_20231113_BCG.csv']}, '20231115': {'BCG': ['../dataset/data\\06\\BCG\\06_20231115_BCG.csv']}, '20231116': {'BCG': ['../dataset/data\\06\\BCG\\06_20231116_BCG.csv']}}, '07': {'20231111': {'BCG': ['../dataset/data\\07\\BCG\\07_20231111_BCG.csv'], 'RR': ['../dataset/data\\07\\Reference\\RR\\07_20231111_RR.csv']}, '20231112': {'BCG': ['../dataset/data\\07\\BCG\\07_20231112_BCG.csv'], 'RR': ['../dataset/data\\07\\Reference\\RR\\07_20231112_RR.csv']}, '20231113': {'BCG': ['../dataset/data\\07\\BCG\\07_20231113_BCG.csv' ...
# ____________*******************&&&&&&&&&&&&&&&&^^^^^^^^^^$$$$$$$$$$
# Subject 01: 6 dates, 6 have BCG, 2 have RR reference
# Subject 02: 7 dates, 7 have BCG, 2 have RR reference
# Subject 03: 6 dates, 6 have BCG, 2 have RR reference
# Subject 04: 7 dates, 7 have BCG, 2 have RR reference
# Subject 05: 7 dates, 7 have BCG, 2 have RR reference
# Subject 06: 6 dates, 6 have BCG, 2 have RR reference
# Subject 07: 6 dates, 6 have BCG, 2 have RR reference
# Subject 08: 7 dates, 7 have BCG, 2 have RR reference
# Subject 09: 7 dates, 7 have BCG, 2 have RR reference
# Subject 10: 7 dates, 7 have BCG, 2 have RR reference
# Subject 11: 7 dates, 7 have BCG, 2 have RR reference
# Subject 12: 7 dates, 7 have BCG, 2 have RR reference
# Subject 13: 5 dates, 5 have BCG, 1 have RR reference
# Subject 14: 6 dates, 6 have BCG, 2 have RR reference
# Subject 15: 7 dates, 7 have BCG, 1 have RR reference
# Subject 16: 7 dates, 7 have BCG, 2 have RR reference
# Subject 17: 5 dates, 5 have BCG, 1 have RR reference
# Subject 18: 7 dates, 7 have BCG, 3 have RR reference
# Subject 19: 7 dates, 7 have BCG, 2 have RR reference
# Subject 20: 7 dates, 7 have BCG, 2 have RR reference
# Subject 21: 7 dates, 7 have BCG, 0 have RR reference
# Subject 22: 6 dates, 6 have BCG, 0 have RR reference
# Subject 23: 6 dates, 6 have BCG, 0 have RR reference
# Subject 24: 7 dates, 7 have BCG, 0 have RR reference
# Subject 25: 7 dates, 7 have BCG, 0 have RR reference
# Subject 26: 7 dates, 7 have BCG, 0 have RR reference
# Subject 27: 7 dates, 7 have BCG, 0 have RR reference
# Subject 28: 7 dates, 7 have BCG, 0 have RR reference
# Subject 29: 7 dates, 7 have BCG, 0 have RR reference
# Subject 30: 6 dates, 6 have BCG, 0 have RR reference
# Subject 31: 7 dates, 7 have BCG, 2 have RR reference
# Subject 32: 7 dates, 7 have BCG, 2 have RR reference
#
# Example entries for subject 01:
#   Date 20231104: has BCG×1, RR×1, resp×0
#   Date 20231105: has BCG×1, RR×1, resp×0
#   Date 20231106: has BCG×1, RR×0, resp×0
#   Date 20231107: has BCG×1, RR×0, resp×0
#   Date 20231108: has BCG×1, RR×0, resp×0
#   Date 20231109: has BCG×1, RR×0, resp×0

# %%
import os
import pandas as pd
import numpy as np
from scipy.signal import resample_poly
from math import gcd

#— parse filenames —
def parse_filename(fn):
    subj, date, kind = os.path.splitext(fn)[0].split("_")
    return subj, date, kind  # e.g. "01","20231104","BCG"

#— load raw BCG CSV —
def load_bcg_csv(path):
    df = pd.read_csv(path)
    sig = df.iloc[:,0].astype(float).to_numpy()
    fs  = float(df.iloc[0,2])
    return sig, fs

#— load RR CSV (reference) —
def load_rr_csv(path):
    """
    Load Reference RR CSV with columns:
      Timestamp (yyyy/MM/dd H:mm:ss), Heart Rate (bpm), RR Interval in seconds
    Returns:
      times: 1‑d array of seconds (float) from first beat
      hr:    1‑d array of heart‑rate (bpm)
    """
    df = pd.read_csv(path)
    # parse the Timestamp strings:
    dt = pd.to_datetime(df.iloc[:,0], format="%Y/%m/%d %H:%M:%S")
    # convert to seconds since first timestamp
    t_secs = (dt.astype(np.int64) / 1e9)  - (dt.astype(np.int64).iloc[0] / 1e9)
    hr     = df.iloc[:,1].astype(float).to_numpy()
    return t_secs.to_numpy(), hr

#— rational resample via polyphase (no aliasing) —
def resample_signal(sig, orig_fs, target_fs):
    up, down = int(target_fs), int(orig_fs)
    g = gcd(up,down)
    up//=g; down//=g
    return resample_poly(sig.astype(float), up, down)

# %% [markdown]
# #### loading and pairing each patient's bcg with its reference

# %%
# discover all BCG & RR paths
DATA = "../dataset/data"
pairs = []   # list of (subj, date, bcg_path, rr_path_or_None)
for subj in sorted(os.listdir(DATA)):
  bdir = os.path.join(DATA,subj,"BCG")
  rdir = os.path.join(DATA,subj,"Reference","RR")
  if not os.path.isdir(bdir): continue
  bcg_files = [f for f in os.listdir(bdir) if f.endswith("_BCG.csv")]
  rr_files  = os.path.isdir(rdir) and [f for f in os.listdir(rdir) if f.endswith("_RR.csv")] or []
  for bfn in bcg_files:
    subj_,date,kind = parse_filename(bfn)
    # find matching rr
    match_rr = None
    for rfn in rr_files:
      if parse_filename(rfn)[1]==date:
        match_rr = os.path.join(rdir,rfn)
    pairs.append((subj, date,
                  os.path.join(bdir,bfn),
                  match_rr))
# quick summary
print(f"Found {len(pairs)} BCG nights, of which {sum(1 for p in pairs if p[3])} have RR.")
print(pairs)
# Out:
# Found 212 BCG nights, of which 42 have RR.
05_20231109_BCG.csv', None), ('06', '20231110', '../dataset/data\\06\\BCG\\06_20231110_BCG.csv', '../dataset/data\\06\\Reference\\RR\\06_20231110_RR.csv'), ('06', '20231111', '../dataset/data\\06\\BCG\\06_20231111_BCG.csv', '../dataset/data\\06\\Reference\\RR\\06_20231111_RR.csv'), ('06', '20231112', '../dataset/data\\06\\BCG\\06_20231112_BCG.csv', None), ('06', '20231113', '../dataset/data\\06\\BCG\\06_20231113_BCG.csv', None), ('06', '20231115', '../dataset/data\\06\\BCG\\06_20231115_BCG.csv', None), ('06', '20231116', '../dataset/data\\06\\BCG\\06_20231116_BCG.csv', None), ('07', '20231111', '../dataset/data\\07\\BCG\\07_20231111_BCG.csv', '../dataset/data\\07\\Reference\\RR\\07_20231111_RR.csv'), ('07', '20231112', '../dataset/data\\07\\BCG\\07_20231112_BCG.csv', '../dataset/data\\07\\Reference\\RR\\07_20231112_RR.csv'), ('07', '20231113', '../dataset/data\\07\\BCG\\07_20231113_BCG.csv', None), ('07', '20231114', '../dataset/data\\07\\BCG\\07_20231114_BCG.csv', None), ('07', '20231115', '../dataset/data\\07\\BCG\\ ...

# %% [markdown]
# ##### paired bcg and corresponding RR ref files

# %%
# now filter to only those pairs with an RR reference
paired = [(s,d,bcg,rr) for s,d,bcg,rr in pairs if rr is not None]
paired
# Out:
# [('01',
#   '20231104',
#   '../dataset/data\\01\\BCG\\01_20231104_BCG.csv',
#   '../dataset/data\\01\\Reference\\RR\\01_20231104_RR.csv'),
#  ('01',
#   '20231105',
#   '../dataset/data\\01\\BCG\\01_20231105_BCG.csv',
#   '../dataset/data\\01\\Reference\\RR\\01_20231105_RR.csv'),
#  ('02',
#   '20231103',
#   '../dataset/data\\02\\BCG\\02_20231103_BCG.csv',
#   '../dataset/data\\02\\Reference\\RR\\02_20231103_RR.csv'),
#  ('02',
#   '20231104',
#   '../dataset/data\\02\\BCG\\02_20231104_BCG.csv',
#   '../dataset/data\\02\\Reference\\RR\\02_20231104_RR.csv'),
#  ('03',
#   '20231103',
#   '../dataset/data\\03\\BCG\\03_20231103_BCG.csv',
#   '../dataset/data\\03\\Reference\\RR\\03_20231103_RR.csv'),
#  ('03',
#   '20231105',
#   '../dataset/data\\03\\BCG\\03_20231105_BCG.csv',
#   '../dataset/data\\03\\Reference\\RR\\03_20231105_RR.csv'),
#  ('04',
#   '20231103',
#   '../dataset/data\\04\\BCG\\04_20231103_BCG.csv',
#   '../dataset/data\\04\\Reference\\RR\\04_20231103_RR.csv'),
#  ('04',
#   '20231104',
#   '../dataset/data\\04\\BCG\\04_20231104_BCG.csv',
#   '../dataset/data\\04\\Reference\\RR\\04_20231104_RR.csv'),
#  ('05',
#   '20231103',
#   '../dataset/data\\05\\BCG\\05_20231103_BCG.csv',
#   '../dataset/data\\05\\Reference\\RR\\05_20231103_RR.csv'),
#  ('05',
#   '20231104',
#   '../dataset/data\\05\\BCG\\05_20231104_BCG.csv',
#   '../dataset/data\\05\\Reference\\RR\\05_20231104_RR.csv'),
#  ('06',
#   '20231110',
#   '../dataset/data\\06\\BCG\\06_20231110_BCG.csv',
#   '../dataset/data\\06\\Reference\\RR\\06_20231110_RR.csv'),
#  ('06',
#   '20231111',
#   '../dataset/data\\06\\BCG\\06_20231111_BCG.csv',
#   '../dataset/data\\06\\Reference\\RR\\06_20231111_RR.csv'),
#  ('07',
#   '20231111',
#   '../dataset/data\\07\\BCG\\07_20231111_BCG.csv',
#   '../dataset/data\\07\\Reference\\RR\\07_20231111_RR.csv'),
#  ('07',
#   '20231112',
#   '../dataset/data\\07\\BCG\\07_20231112_BCG.csv',
#   '../dataset/data\\07\\Reference\\RR\\07_20231112_RR.csv'),
#  ('08',
#   '20231110',
#   '../dataset/data\\08\\BCG\\08_20231110_BCG.csv',
#   '../dataset/data\\08\\Reference\\RR\\08_20231110_RR.csv'),
#  ('08',
#   '20231111',
#   '../dataset/data\\08\\BCG\\08_20231111_BCG.csv',
#   '../dataset/data\\08\\Reference\\RR\\08_20231111_RR.csv'),
#  ('09',
#   '20231110',
#   '../dataset/data\\09\\BCG\\09_20231110_BCG.csv',
#   '../dataset/data\\09\\Reference\\RR\\09_20231110_RR.csv'),
#  ('09',
#   '20231111',
#   '../dataset/data\\09\\BCG\\09_20231111_BCG.csv',
#   '../dataset/data\\09\\Reference\\RR\\09_20231111_RR.csv'),
#  ('10',
#   '20231110',
#   '../dataset/data\\10\\BCG\\10_20231110_BCG.csv',
#   '../dataset/data\\10\\Reference\\RR\\10_20231110_RR.csv'),
#  ('10',
#   '20231111',
#   '../dataset/data\\10\\BCG\\10_20231111_BCG.csv',
#   '../dataset/data\\10\\Reference\\RR\\10_20231111_RR.csv'),
#  ('11',
#   '20231117',
#   '../dataset/data\\11\\BCG\\11_20231117_BCG.csv',
#   '../dataset/data\\11\\Reference\\RR\\11_20231117_RR.csv'),
#  ('11',
#   '20231118',
#   '../dataset/data\\11\\BCG\\11_20231118_BCG.csv',
#   '../dataset/data\\11\\Reference\\RR\\11_20231118_RR.csv'),
#  ('12',
#   '20231117',
#   '../dataset/data\\12\\BCG\\12_20231117_BCG.csv',
#   '../dataset/data\\12\\Reference\\RR\\12_20231117_RR.csv'),
#  ('12',
#   '20231118',
#   '../dataset/data\\12\\BCG\\12_20231118_BCG.csv',
#   '../dataset/data\\12\\Reference\\RR\\12_20231118_RR.csv'),
#  ('13',
#   '20231121',
#   '../dataset/data\\13\\BCG\\13_20231121_BCG.csv',
#   '../dataset/data\\13\\Reference\\RR\\13_20231121_RR.csv'),
#  ('14',
#   '20231118',
#   '../dataset/data\\14\\BCG\\14_20231118_BCG.csv',
#   '../dataset/data\\14\\Reference\\RR\\14_20231118_RR.csv'),
#  ('14',
#   '20231122',
#   '../dataset/data\\14\\BCG\\14_20231122_BCG.csv',
#   '../dataset/data\\14\\Reference\\RR\\14_20231122_RR.csv'),
#  ('15',
#   '20231117',
#   '../dataset/data\\15\\BCG\\15_20231117_BCG.csv',
#   '../dataset/data\\15\\Reference\\RR\\15_20231117_RR.csv'),
#  ('16',
#   '20231127',
#   '../dataset/data\\16\\BCG\\16_20231127_BCG.csv',
#   '../dataset/data\\16\\Reference\\RR\\16_20231127_RR.csv'),
#  ('16',
#   '20231128',
#   '../dataset/data\\16\\BCG\\16_20231128_BCG.csv',
#   '../dataset/data\\16\\Reference\\RR\\16_20231128_RR.csv'),
#  ('17',
#   '20231126',
#   '../dataset/data\\17\\BCG\\17_20231126_BCG.csv',
#   '../dataset/data\\17\\Reference\\RR\\17_20231126_RR.csv'),
#  ('18',
#   '20231126',
#   '../dataset/data\\18\\BCG\\18_20231126_BCG.csv',
#   '../dataset/data\\18\\Reference\\RR\\18_20231126_RR.csv'),
#  ('18',
#   '20231127',
#   '../dataset/data\\18\\BCG\\18_20231127_BCG.csv',
#   '../dataset/data\\18\\Reference\\RR\\18_20231127_RR.csv'),
#  ('18',
#   '20231128',
#   '../dataset/data\\18\\BCG\\18_20231128_BCG.csv',
#   '../dataset/data\\18\\Reference\\RR\\18_20231128_RR.csv'),
#  ('19',
#   '20231126',
#   '../dataset/data\\19\\BCG\\19_20231126_BCG.csv',
#   '../dataset/data\\19\\Reference\\RR\\19_20231126_RR.csv'),
#  ('19',
#   '20231127',
#   '../dataset/data\\19\\BCG\\19_20231127_BCG.csv',
#   '../dataset/data\\19\\Reference\\RR\\19_20231127_RR.csv'),
#  ('20',
#   '20231127',
#   '../dataset/data\\20\\BCG\\20_20231127_BCG.csv',
#   '../dataset/data\\20\\Reference\\RR\\20_20231127_RR.csv'),
#  ('20',
#   '20231128',
#   '../dataset/data\\20\\BCG\\20_20231128_BCG.csv',
#   '../dataset/data\\20\\Reference\\RR\\20_20231128_RR.csv'),
#  ('31',
#   '20240120',
#   '../dataset/data\\31\\BCG\\31_20240120_BCG.csv',
#   '../dataset/data\\31\\Reference\\RR\\31_20240120_RR.csv'),
#  ('31',
#   '20240121',
#   '../dataset/data\\31\\BCG\\31_20240121_BCG.csv',
#   '../dataset/data\\31\\Reference\\RR\\31_20240121_RR.csv'),
#  ('32',
#   '20240127',
#   '../dataset/data\\32\\BCG\\32_20240127_BCG.csv',
#   '../dataset/data\\32\\Reference\\RR\\32_20240127_RR.csv'),
#  ('32',
#   '20240128',
#   '../dataset/data\\32\\BCG\\32_20240128_BCG.csv',
#   '../dataset/data\\32\\Reference\\RR\\32_20240128_RR.csv')]

# %%
# parameters
TARGET_FS = 50.0
WIN_SEC   = 6*60
WIN_SAMPS = int(WIN_SEC*TARGET_FS)

bcg_windows = {}
rr_windows  = {}

for subj, date, bcg_path, rr_path in paired:
    # 1) load & resample BCG → 50 Hz
    bcg, fs0 = load_bcg_csv(bcg_path)
    bcg50    = resample_signal(bcg, fs0, TARGET_FS)

    # 2) load & interpolate RR → 50 Hz grid
    rr_t, rr_hr = load_rr_csv(rr_path)
    uni_t = np.arange(0, rr_t.max(), 1.0/TARGET_FS)
    rr50  = np.interp(uni_t, rr_t, rr_hr)

    # 3) how many full windows?
    nwin_b = len(bcg50) // WIN_SAMPS
    nwin_r = len(rr50)  // WIN_SAMPS
    nwin   = min(nwin_b, nwin_r)

    # 4) slice
    bcg_windows[(subj,date)] = [ bcg50[i*WIN_SAMPS:(i+1)*WIN_SAMPS] for i in range(nwin) ]
    rr_windows[(subj,date)]  = [ rr50[i*WIN_SAMPS:(i+1)*WIN_SAMPS]  for i in range(nwin) ]

# sanity check
for key in list(bcg_windows):
    print(key,
          "→", len(bcg_windows[key]), "windows BCG  |",
          len(rr_windows.get(key,[])), "windows RR")
# Out:
# ('01', '20231104') → 71 windows BCG  | 71 windows RR
# ('01', '20231105') → 108 windows BCG  | 108 windows RR
# ('02', '20231103') → 89 windows BCG  | 89 windows RR
# ('02', '20231104') → 83 windows BCG  | 83 windows RR
# ('03', '20231103') → 66 windows BCG  | 66 windows RR
# ('03', '20231105') → 94 windows BCG  | 94 windows RR
# ('04', '20231103') → 92 windows BCG  | 92 windows RR
# ('04', '20231104') → 90 windows BCG  | 90 windows RR
# ('05', '20231103') → 82 windows BCG  | 82 windows RR
# ('05', '20231104') → 98 windows BCG  | 98 windows RR
# ('06', '20231110') → 77 windows BCG  | 77 windows RR
# ('06', '20231111') → 78 windows BCG  | 78 windows RR
# ('07', '20231111') → 128 windows BCG  | 128 windows RR
# ('07', '20231112') → 98 windows BCG  | 98 windows RR
# ('08', '20231110') → 72 windows BCG  | 72 windows RR
# ('08', '20231111') → 86 windows BCG  | 86 windows RR
# ('09', '20231110') → 100 windows BCG  | 100 windows RR
# ('09', '20231111') → 87 windows BCG  | 87 windows RR
# ('10', '20231110') → 75 windows BCG  | 75 windows RR
# ('10', '20231111') → 78 windows BCG  | 78 windows RR
# ('11', '20231117') → 72 windows BCG  | 72 windows RR
# ('11', '20231118') → 78 windows BCG  | 78 windows RR
# ('12', '20231117') → 83 windows BCG  | 83 windows RR
# ('12', '20231118') → 79 windows BCG  | 79 windows RR
# ('13', '20231121') → 69 windows BCG  | 69 windows RR
# ('14', '20231118') → 95 windows BCG  | 95 windows RR
# ('14', '20231122') → 104 windows BCG  | 104 windows RR
# ('15', '20231117') → 89 windows BCG  | 89 windows RR
# ('16', '20231127') → 96 windows BCG  | 96 windows RR
# ('16', '20231128') → 102 windows BCG  | 102 windows RR
# ('17', '20231126') → 79 windows BCG  | 79 windows RR
# ('18', '20231126') → 78 windows BCG  | 78 windows RR
# ('18', '20231127') → 77 windows BCG  | 77 windows RR
# ('18', '20231128') → 82 windows BCG  | 82 windows RR
# ('19', '20231126') → 90 windows BCG  | 90 windows RR
# ('19', '20231127') → 94 windows BCG  | 94 windows RR
# ('20', '20231127') → 74 windows BCG  | 74 windows RR
# ('20', '20231128') → 70 windows BCG  | 70 windows RR
# ('31', '20240120') → 98 windows BCG  | 98 windows RR
# ('31', '20240121') → 86 windows BCG  | 86 windows RR
# ('32', '20240127') → 76 windows BCG  | 76 windows RR
# ('32', '20240128') → 68 windows BCG  | 68 windows RR

# %%
bcg_windows[('01', '20231104')]
# Out:
# [array([-60.30089056, -94.25285993, -84.24473276, ..., -60.89721647,
#         -5.42617156e-01,  2.13490306e+01,  4.79392261e+01], shape=(18000,)),
#  array([  45.33851181,   49.42429766,  -11.88748863, ..., -584.81923427,
#         -341.46669598, -102.30066076], shape=(18000,)),
#  array([ -59.53892364,   17.00748448,   -1.9322793 , ...,   25.80897665,
#         -123.28175999,   -0.68574994], shape=(18000,)),
#  array([  65.31396592,  -51.19091208, -130.61933894, ..., -957.47481792,
#         -853.75611004, -156.46063039], shape=(18000,)),
#  array([-482.63657829, -171.53599985, -435.60534744, ...,  -46.58783743,
#          -46.78616149,  -43.31699724], shape=(18000,)),
#  array([-40.16105076, -43.25119791, -41.98694858, ..., -50.40952661,
#         -55.57834026, -59.62489512], shape=(18000,)),
#  array([-57.64644209, -59.96267089, -67.8226076 , ..., -76.25068267,
#         -84.10377264, -80.05186165], shape=(18000,)),
#  array([ -73.45048318,  -83.8923423 ,  -90.92240415, ..., -112.52986986,
#         -170.12605251, -100.08206208], shape=(18000,)),
#  array([-152.59184109, -495.79210479, -441.69459765, ..., 4129.59012574,
#         3438.00539641, 2808.01845126], shape=(18000,)),
#  array([4385.2120228 , 1906.39833715, -930.57227799, ...,   14.71574091,
#         -147.42755119, -198.93963463], shape=(18000,)),
#  array([263.0597285 , 674.3281272 , 327.63229496, ..., -72.54587127,
#         -77.66708729, -89.35404836], shape=(18000,)),
#  array([-106.46899648,   88.55487243,   43.9885422 , ...,   38.3892948 ,
#          364.89606016,  320.05278814], shape=(18000,)),
#  array([   55.22771027,   416.42680661,    83.54215027, ...,
#         -1071.81039907, -1029.31231023,  -824.13858589], shape=(18000,)),
#  array([-1573.99290319, -1517.6506505 , -3118.49885115, ...,
#           681.2319279 ,   888.4103811 ,   898.65828665], shape=(18000,)),
#  array([ 453.32342048,  381.94069241,  929.68018295, ..., -244.31844255,
#         -154.12459716,  -87.39629502], shape=(18000,)),
#  array([-134.55699299, -155.54727587,  -43.69878458, ..., -183.25771708,
#         -108.21853532, -151.87364265], shape=(18000,)),
#  array([-191.31241269, -299.06812169, -141.9572351 , ...,   47.65289541,
#           27.78525039,   88.55716154], shape=(18000,)),
#  array([532.65556954, 881.88860173, 218.40413617, ..., 346.03269458,
#          84.83763438,  12.08287367], shape=(18000,)),
#  array([  42.66640843,   91.05950825,   44.14183807, ..., -320.86465495,
#          102.01152771, 1007.34259673], shape=(18000,)),
#  array([  1214.5462515 ,    811.11793581,   2615.01830482, ...,
#         -32796.73861959, -32980.00962918, -32350.76789277], shape=(18000,)),
#  array([-33554.02495944, -31526.45051711, -34850.01906871, ...,
#           -734.05491907,   -199.789245  ,   -151.37095718], shape=(18000,)),
#  array([-399.20063538, -537.77099526, -554.41318425, ...,   73.0109329 ,
#          -16.39611767,  -69.60490706], shape=(18000,)),
#  array([  40.15623749,  -51.62076868,  124.22220777, ..., -136.41972376,
#         -142.00303172, -134.5620992 ], shape=(18000,)),
#  array([-115.07980624, -136.94407558, -187.07548143, ...,  -23.40862147,
#         -117.64621366,  -41.36600941], shape=(18000,))]
